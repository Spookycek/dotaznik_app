# %%
import warnings
warnings.filterwarnings('ignore')

import ipywidgets as widgets
from ipywidgets import Video
from IPython.display import display, clear_output
import random
import numpy as np
import glob 
import pyrebase
import uuid

# %%
firebaseConfig = {
  "apiKey": "AIzaSyDkLvZdXjo95GuXSJmDAeVyG8h_EOGYUWY",
  "authDomain": "dotaznik-app.firebaseapp.com",
  "databaseURL": "https://dotaznik-app-default-rtdb.europe-west1.firebasedatabase.app",
  "projectId": "dotaznik-app",
  "storageBucket": "dotaznik-app.appspot.com",
  "messagingSenderId": "472313295682",
  "appId": "1:472313295682:web:c7b2598df7c9c1d7d50edb",
  "measurementId": "G-RXL41NLLZ6"
};

# %%
#inicializacia databazy
firebase=pyrebase.initialize_app(firebaseConfig)
db = firebase.database()

# %%
from ipywidgets import Layout, Button, Box
box_layout = Layout(display='flex',
                    flex_flow='column',
                    align_items='center',
                    width='100%')
ram_layout = Layout(border='solid',
                   margin = "0px 350px 0px 350px",
                   align_items='center',
                   justify_content = 'center',
                   padding = "15px 50px 15px 50px")

# %%
vysledky = []
vid_dir = 'videos'
zaklad_dir ="videos/vid_dotaznik"
sal_dir ="videos/solmap_dotaznik"
smooth_dir = "videos/smooth_dotaznik"
num_vid = 1
press_num = 0

# %%
def picVid(vid_dir):
    files = []
    vid =""
    for file in glob.glob(vid_dir+"/*.mp4"):
        files.append(file.split("/")[2].split(".")[0])

    np.array(files)
    files = np.unique(files)
    rn = random.choice(files)
    #print(rn)
    for file in(glob.glob(vid_dir+"/*.mp4")): 
        #print(file)
        nazov = file.split("/")[2].split(".")[0]
        #print(nazov, type(nazov),rn, type(rn))
        if(nazov == rn):
            #print(file)
            vid = file
    return vid

# %%
def global_but(event):
    global_page.close()
    text_end = widgets.HTML("<h2>Ďakujem za váš čas</h2>")
    #text_9 = widgets.HTML(str(vysledky))
    end = widgets.VBox([text_end],layout = ram_layout)
    
    
    global_push ={
        "zvysena_dovera" : global_1.value,
        "nas_odporuc" : global_2.value,
        "pripomienky" : volny_text_global.value
    }
    
    ran_z = uuid.uuid4().hex
    db.child("Global_{}".format(ran_z)).set(global_push)
    

    
    j.center = end

# %%
# def click_play(event):
#     if( j.center.children[0].children[1].play == True ):
#         j.center.children[0].children[1].pause = True 
#         j.center.children[0].children[1].autoplay = False
#         j.center.children[0].children[2].autoplay = False
#         j.center.children[0].children[3].autoplay = False

#     else:
#         j.center.children[0].children[1].autoplay = True
#         j.center.children[0].children[2].autoplay = True
#         j.center.children[0].children[3].autoplay = True
def click_plussize(event):
    if(j.center.children[0].children[2].width == "90"):

        j.center.children[0].children[1].width = 180
        j.center.children[0].children[1].height = 180
        
        j.center.children[0].children[2].width  = 180
        j.center.children[0].children[2].height = 180
        
        j.center.children[0].children[3].width  = 180
        j.center.children[0].children[3].height = 180
        
def click_minussize(event):
    if(j.center.children[0].children[2].width == "180"):
        j.center.children[0].children[1].width = 90
        j.center.children[0].children[1].height = 90
        
        j.center.children[0].children[2].width  = 90
        j.center.children[0].children[2].height = 90
        
        j.center.children[0].children[3].width  = 90
        j.center.children[0].children[3].height = 90

# %%
#global otazky
volny_text_global = widgets.Text(value='')
global_1 = widgets.ToggleButtons(
            options=['Áno', 'Nie']
        )
global_2= widgets.ToggleButtons(
            options=['Áno', 'Nie']
        )
button_global = widgets.Button(
            description='Odoslať',
            tooltip='Odoslať',
            style={'description_width': 'initial'}
        )
button_global.on_click(global_but)
text_global = widgets.HTML("<h2> Pomohli Vám videa vysvetliteľnosti, zvýšiť dôveru v náš model? </h2>")
text_global2 = widgets.HTML("<h2> Nasledovali by ste odporúčania takéhoto modelu? </h2>")
text_global3= widgets.HTML("<h2> Priestor pre doplnenie Vašich pripomienok alebo návrhov (nepovinné) </h2>")

global_page = widgets.VBox([text_global, global_1, text_global2, global_2, text_global3, volny_text_global, button_global], 
                                 
                                layout = ram_layout)

# %%
#tlačidla
press_num = 0
def on_button_clicked2(event):
    
    global press_num 

    zaznam = [grand.value, grand2.value, vys.value, vys2.value, volny_text.value]
    vysledky.append(zaznam)

    zaklad_vid2 = picVid(zaklad_dir)
    nazov2 = zaklad_vid2.split("/")[2]
    sal_vid2 = sal_dir+"/"+nazov2
    smooth_vid2 = smooth_dir+"/"+nazov2
    #print(zaklad_vid2,nazov2,sal_vid2,smooth_vid2)
    
    video_zaklad2 = Video.from_file(zaklad_vid2, play = True, width= 90, height = 90)
    video_sal2 = Video.from_file(sal_vid2, play = True, width= 90, height = 90)
    video_smooth2 = Video.from_file(smooth_vid2, play = True, width= 90, height = 90)
    text_test_n = widgets.HTML(value="<h2>"+str(press_num+1)+"/10"+"</h2>")
    vid_buttons_n = widgets.VBox([but_play,but_size])
    videa_new = widgets.HBox([vid_buttons_n,video_zaklad2,video_sal2, video_smooth2], layout = vid_layout)
    but_play.on_click(click_plussize)
    but_size.on_click(click_minussize)
    
    page_look_new = widgets.VBox([
                                  videa_new,
                                  text_1, 
                                  grand, 
                                  text_2,
                                  grand2, 
                                  text_3,
                                  text_3vys,
                                  vys, 
                                  text_4, 
                                  text_4vys,
                                  vys2, 
                                  text_5,
                                  volny_text, 
                                  button_test], 
                                 
                                layout = ram_layout)

    page_look.close()
    j.center = page_look_new
    
   
    
    push_zaznam = {
            "Velkost_videa" : grand.value,
            "Lepsia_vys" : grand2.value,
            "zrozumiteľnosť" : vys.value,
            "spravnost_modelu" : vys2.value,
            "Lub_text" : volny_text.value
        
    }
    
    db.push(push_zaznam)
    
    if(press_num == 10):
        page_look_new.close()
        j.center = global_page
    press_num = press_num + 1
    
    #reset values
    vys.value = 3
    vys2.value = 3
    volny_text.value = ""

# %%
vid_layout = Layout(margin = "100")

# %%
################################# povedzme úvodna stranka

zaklad_vid = picVid(zaklad_dir)
nazov = zaklad_vid.split("/")[2]
sal_vid = sal_dir+"/"+nazov
smooth_vid = smooth_dir+"/"+nazov

video_zaklad = Video.from_file(zaklad_vid, autoplay = True, width= 90, height = 90)
video_sal = Video.from_file(sal_vid, autoplay = True, width= 90, height = 90)
video_smooth = Video.from_file(smooth_vid, autoplay = True, width= 90, height = 90)
text_test = widgets.HTML(value="<h2>"+str(press_num)+"/10"+"</h2>")
but_play = widgets.Button(
            description='Zväčšiť video',
            tooltip='Zväčšiť video',
            style={'description_width': 'initial'}
        )

but_size = widgets.Button(
            description='Zmenšiť video',
            tooltip='zmenšiť video',
            style={'description_width': 'initial'}
        )


vid_buttons = widgets.VBox([but_play,but_size])

videa = widgets.HBox([vid_buttons,video_zaklad,video_sal, video_smooth], layout = vid_layout)


grand = widgets.ToggleButtons(
            options=['Áno', 'Nie']
        )
grand2 = widgets.ToggleButtons(
            options=['Druhé', 'Tretie']
        )
vys2 = widgets.IntSlider(
        value=3, # default value
        min=0, 
        max=5,
        step=1,
        style={'description_width': 'initial', 'handle_color': '#16a085'} 
    )
vys = widgets.IntSlider(
            value=3, # default value
            min=0, 
            max=5,
            step=1,
            style={'description_width': 'initial', 'handle_color': '#16a085'} 
        )
button_test = widgets.Button(
            description='Ďalej',
            tooltip='Ďalšie video',
            style={'description_width': 'initial'}
        )
output = widgets.Output()

button_test.on_click(on_button_clicked2)
but_play.on_click(click_plussize)
but_size.on_click(click_minussize)
vbox_result = widgets.VBox([button_test])
text_0 = widgets.HTML(value= "<h1>Metódy hlbokého učenia a ich vysvetliteľnosť použitá pre klasifikáciu kĺzavého pohybu pľúc</h1>")
text_1 = widgets.HTML(value="<h2>Je dané video dostatočne spoľahlivé pre diagnostiku kĺzavého pohybu??</h2>")
#text_2= widgets.HTML(value="<h2>Náš model klasifikoval video ako" +klas+ "je video správne označené? </h2>")
text_2 = widgets.HTML(value="<h2>Ktoré video vysvetliteľnosti lepšie zachytáva príznaky výskytu/absencie kĺzavého pohybu pľúc?</h2>")
text_3= widgets.HTML(value="<h2>Na škále od 1 do 5, ako je vami zvolená vysvetliteľnosť zrozumieteľná?</h2>")
text_3vys = widgets.HTML(value="<h4>1 - nedostatočne 2 - dostatočne 3 - priemerne 4 - dobre 5 - veľmi dobre</h4>")
text_4= widgets.HTML(value="<h2>Na škále od 1 do 5, ako dobre sa náš model zameriava na príznaky kĺzavého pohybu pľúc? </h2>")
text_4vys = widgets.HTML(value="<h4>1 - nedostatočne 2 - dostatočne 3 - priemerne 4 - dobre 5 - veľmi dobre</h4>")

text_5= widgets.HTML(value="<h2>V nasledujúcom okne, môžete doplniť prípadné poznámky (ľubovoľné)</h2>")

volny_text = widgets.Text(value='')
page_look = widgets.VBox([videa,text_1, grand, text_2,grand2, text_3,text_3vys,vys, text_4,text_4vys, vys2, text_5, volny_text, button_test], 
                    layout = ram_layout)

#print(vys.value)
# Out:
# videos\solmap_dotaznik\62_0.mp4 videos\smooth_dotaznik\62_0.mp4

# %%
def clicked_start(event):
    page_look75.close()
    j.center = page_look

# %%
button_start = widgets.Button(
            description='Začať dotazník',
            tooltip='Začať dotazník',
            style={'description_width': 'initial'}
        )
file = open("uvodka.png", "rb")
image = file.read()
obr = widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400,
)
button_start.on_click(clicked_start)
text_opis = widgets.HTML(value="""<h2 style="text-align: justify">Dobrý deň.<br>
Som študentom inžinierského štúdia na Technickej univerzite v Košiciach v odbore Hospodárska informatika a chcel by som Vás požiadať o vyplnenie dotazníka, ktorý je anonymný a bude použitý v mojej diplomovej práci. 
V mojej diplomovej práci sa venujeme využitiu hlbokého učenia pri analýze videosekvencií so zameraním na vysvetliteľnosť. Konkrétne sa venujeme klasifikácii prítomnosti kĺzavého pohybu pľúc z videí zozbieraných pri sonografickom vyšetrení a zameriavame sa na vysvetliteľnosť tejto klasifikácie. Vysvetliteľnosť v jednoduchosti povedané zobrazuje ako sa náš model pozerá na vstupné dáta a zobrazuje na základe čoho sa daný model rozhodol zaradiť konkrétny prípad do danej triedy, čím je oblasť svetlešia (červenšia) tým väčšiu váhu daná oblasť pre náš model má. 
</h2>""")
text_opis2 = widgets.HTML(value="""<h2 style="text-align: justify">Nasledujúci dotazník Vám zaberie približne 10minút Vášho času, dotazník obsahuje 5 lokálnych otázok pre 10 konkrétnych videí s vysvetliteľnosťou a na záver 2 globálne otázky ohľadom nášho modelu. V úvode dotazníka sa Vám zobrazia tri videá, kde prvé video predstavuje originálne video zo sonografického vyšetrenia, druhé a tretie video zobrazujú dve rôzne metódy vysvetliteľnosti použité pre náš model. Za čas venovaný vyplneniu dotazníka Vám vopred ďakujem.</h2>""")
page_look75 = widgets.VBox([text_opis,obr,text_opis2, button_start],layout=ram_layout)

# %%
from ipywidgets import AppLayout
j = AppLayout(header = None,
          left_sidebar=None,
          center=page_look75, 
          right_sidebar=None
          )

# %%
display(j)
# Out:
# AppLayout(children=(VBox(children=(HTML(value='<h2>Dobrý deň. Nasledujúci dotazník Vám zaberie maximálne 10 mi…
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonGPU\lib\site-packages\pyrebase\pyrebase.py in raise_detailed_error(request_object)
#     511     try:
# --> 512         request_object.raise_for_status()
#     513     except HTTPError as e:
#
# ~\anaconda3\envs\PythonGPU\lib\site-packages\requests\models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 401 Client Error: Unauthorized for url: https://dotaznik-app-default-rtdb.europe-west1.firebasedatabase.app/.json
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ...
